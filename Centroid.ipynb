# %%
# Nhập thư viện
import numpy as np
import pandas as pd

# %%
# Load dữ liệu
def loadExcel(filename):
  return pd.read_excel(filename)

# %%
# tạo tập train test (chia data_train (gộp X_train và y_train) và X_test và y_test)
def splitTrainTest(data, target, ratio = 0.25): # data --> frame
    from sklearn.model_selection import train_test_split
    data_X = data.drop([target], axis = 1)
    data_y = data[[target]]
    data_train, X_test, y_train, y_test = train_test_split(data_X, data_y, test_size = ratio, random_state = 0)
    data_train = pd.concat([data_train, y_train], axis = 1)
    return data_train, X_test, y_test # đều là dạng frame

# %%
# hàm tính trung bình của từng lớp trong biến target
def mean_class(data_train, target): # tên cột target, data_train là dạng pandas
    df_group = data_train.groupby(by = target).mean() # tất cả các cột đều dạng số, --> frame # sắp xếp theo bảng chữ cái tăng dần(mặc định)
    return df_group # kết quả là dataframe

# %%
# hàm dự đoán dùng khoảng cách euclid
def target_pred(data_group, data_test): # data_test ở dạng mảng, data_group là đã đem tính trung bình các lớp(là df_group)
    dict_ = dict()
    for index, value in enumerate(data_group.values):
        result = np.sqrt(np.sum(((data_test - value)**2), axis = 1)) # khoảng cách euclid
        if index in dict_:
            dict_.append(result)
        else:
            dict_[index] = result # Lưu ý chỗ này không phải là [result] vì result là dạng mảng, nếu thêm vào vậy thì nó chỉ có một phần tử.
    # dict_ kết quả dạng {0: [2.0], 1: [1.0540925533894596]}
    df = pd.DataFrame(dict_) # chuyển sang dạng dataframe
    return df.idxmin(axis = 1) # hàm này tìm cột chưá giá trị nhỏ nhất

##### Có thể phát triển: cho thêm một tham số metric vào hàm, nếu là euclid thì dùng khoảng cách euclid, manhattan thì dùng khoảng cách manhattan.

# %%
### Demo bằng ví dụ Iris

# %%
data = loadExcel('Iris.xls')
data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            iris
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data_train, X_test, y_test = splitTrainTest(data, 'iris', ratio = 0.3)
print(data_train)
print(X_test)
print(y_test)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth             iris
# 60           5.0         2.0          3.5         1.0  Iris-versicolor
# 116          6.5         3.0          5.5         1.8   Iris-virginica
# 144          6.7         3.3          5.7         2.5   Iris-virginica
# 119          6.0         2.2          5.0         1.5   Iris-virginica
# 108          6.7         2.5          5.8         1.8   Iris-virginica
# ..           ...         ...          ...         ...              ...
# 9            4.9         3.1          1.5         0.1      Iris-setosa
# 103          6.3         2.9          5.6         1.8   Iris-virginica
# 67           5.8         2.7          4.1         1.0  Iris-versicolor
# 117          7.7         3.8          6.7         2.2   Iris-virginica
# 47           4.6         3.2          1.4         0.2      Iris-setosa
#
# [105 rows x 5 columns]
#      sepallength  sepalwidth  petallength  petalwidth
# 114          5.8         2.8          5.1         2.4
# 62           6.0         2.2          4.0         1.0
# 33           5.5         4.2          1.4         0.2
# 107          7.3         2.9          6.3         1.8
# 7            5.0         3.4          1.5         0.2
# 100          6.3         3.3          6.0         2.5
# 40           5.0         3.5          1.3         0.3
# 86           6.7         3.1          4.7         1.5
# 76           6.8         2.8          4.8         1.4
# 71           6.1         2.8          4.0         1.3
# 134          6.1         2.6          5.6         1.4
# 51           6.4         3.2          4.5         1.5
# 73           6.1         2.8          4.7         1.2
# 54           6.5         2.8          4.6         1.5
# 63           6.1         2.9          4.7         1.4
# 37           4.9         3.1          1.5         0.1
# 78           6.0         2.9          4.5         1.5
# 90           5.5         2.6          4.4         1.2
# 45           4.8         3.0          1.4         0.3
# 16           5.4         3.9          1.3         0.4
# 121          5.6         2.8          4.9         2.0
# 66           5.6         3.0          4.5         1.5
# 24           4.8         3.4          1.9         0.2
# 8            4.4         2.9          1.4         0.2
# 126          6.2         2.8          4.8         1.8
# 22           4.6         3.6          1.0         0.2
# 44           5.1         3.8          1.9         0.4
# 97           6.2         2.9          4.3         1.3
# 93           5.0         2.3          3.3         1.0
# 26           5.0         3.4          1.6         0.4
# 137          6.4         3.1          5.5         1.8
# 84           5.4         3.0          4.5         1.5
# 27           5.2         3.5          1.5         0.2
# 127          6.1         3.0          4.9         1.8
# 132          6.4         2.8          5.6         2.2
# 59           5.2         2.7          3.9         1.4
# 18           5.7         3.8          1.7         0.3
# 83           6.0         2.7          5.1         1.6
# 61           5.9         3.0          4.2         1.5
# 92           5.8         2.6          4.0         1.2
# 112          6.8         3.0          5.5         2.1
# 2            4.7         3.2          1.3         0.2
# 141          6.9         3.1          5.1         2.3
# 43           5.0         3.5          1.6         0.6
# 10           5.4         3.7          1.5         0.2
#                 iris
# 114   Iris-virginica
# 62   Iris-versicolor
# 33       Iris-setosa
# 107   Iris-virginica
# 7        Iris-setosa
# 100   Iris-virginica
# 40       Iris-setosa
# 86   Iris-versicolor
# 76   Iris-versicolor
# 71   Iris-versicolor
# 134   Iris-virginica
# 51   Iris-versicolor
# 73   Iris-versicolor
# 54   Iris-versicolor
# 63   Iris-versicolor
# 37       Iris-setosa
# 78   Iris-versicolor
# 90   Iris-versicolor
# 45       Iris-setosa
# 16       Iris-setosa
# 121   Iris-virginica
# 66   Iris-versicolor
# 24       Iris-setosa
# 8        Iris-setosa
# 126   Iris-virginica
# 22       Iris-setosa
# 44       Iris-setosa
# 97   Iris-versicolor
# 93   Iris-versicolor
# 26       Iris-setosa
# 137   Iris-virginica
# 84   Iris-versicolor
# 27       Iris-setosa
# 127   Iris-virginica
# 132   Iris-virginica
# 59   Iris-versicolor
# 18       Iris-setosa
# 83   Iris-versicolor
# 61   Iris-versicolor
# 92   Iris-versicolor
# 112   Iris-virginica
# 2        Iris-setosa
# 141   Iris-virginica
# 43       Iris-setosa
# 10       Iris-setosa

# %%
df_group = mean_class(data_train, 'iris')
df_group
# Out:
#                  sepallength  sepalwidth  petallength  petalwidth
# iris
# Iris-setosa         4.994118    3.382353     1.452941    0.229412
# Iris-versicolor     5.921875    2.756250     4.196875    1.306250
# Iris-virginica      6.653846    2.987179     5.597436    2.030769

# %%
#  tính khoảng cách và trả về kết quả lớp có khoảng cách gần nhất
df1 = pd.DataFrame(target_pred(df_group, X_test.values), columns = ['Predict'])
df1
# Out:
#     Predict
# 0         2
# 1         1
# 2         0
# 3         2
# 4         0
# 5         2
# 6         0
# 7         1
# 8         2
# 9         1
# 10        2
# 11        1
# 12        1
# 13        1
# 14        1
# 15        0
# 16        1
# 17        1
# 18        0
# 19        0
# 20        1
# 21        1
# 22        0
# 23        0
# 24        1
# 25        0
# 26        0
# 27        1
# 28        1
# 29        0
# 30        2
# 31        1
# 32        0
# 33        1
# 34        2
# 35        1
# 36        0
# 37        1
# 38        1
# 39        1
# 40        2
# 41        0
# 42        2
# 43        0
# 44        0

# %%
# set index y_test để nối 2 frame
y_test.index = range(0, len(y_test))
y_test.columns = ['Actual']
y_test
# Out:
#              Actual
# 0    Iris-virginica
# 1   Iris-versicolor
# 2       Iris-setosa
# 3    Iris-virginica
# 4       Iris-setosa
# 5    Iris-virginica
# 6       Iris-setosa
# 7   Iris-versicolor
# 8   Iris-versicolor
# 9   Iris-versicolor
# 10   Iris-virginica
# 11  Iris-versicolor
# 12  Iris-versicolor
# 13  Iris-versicolor
# 14  Iris-versicolor
# 15      Iris-setosa
# 16  Iris-versicolor
# 17  Iris-versicolor
# 18      Iris-setosa
# 19      Iris-setosa
# 20   Iris-virginica
# 21  Iris-versicolor
# 22      Iris-setosa
# 23      Iris-setosa
# 24   Iris-virginica
# 25      Iris-setosa
# 26      Iris-setosa
# 27  Iris-versicolor
# 28  Iris-versicolor
# 29      Iris-setosa
# 30   Iris-virginica
# 31  Iris-versicolor
# 32      Iris-setosa
# 33   Iris-virginica
# 34   Iris-virginica
# 35  Iris-versicolor
# 36      Iris-setosa
# 37  Iris-versicolor
# 38  Iris-versicolor
# 39  Iris-versicolor
# 40   Iris-virginica
# 41      Iris-setosa
# 42   Iris-virginica
# 43      Iris-setosa
# 44      Iris-setosa

# %%
df2 = pd.DataFrame(y_test)
df2
# Out:
#              Actual
# 0    Iris-virginica
# 1   Iris-versicolor
# 2       Iris-setosa
# 3    Iris-virginica
# 4       Iris-setosa
# 5    Iris-virginica
# 6       Iris-setosa
# 7   Iris-versicolor
# 8   Iris-versicolor
# 9   Iris-versicolor
# 10   Iris-virginica
# 11  Iris-versicolor
# 12  Iris-versicolor
# 13  Iris-versicolor
# 14  Iris-versicolor
# 15      Iris-setosa
# 16  Iris-versicolor
# 17  Iris-versicolor
# 18      Iris-setosa
# 19      Iris-setosa
# 20   Iris-virginica
# 21  Iris-versicolor
# 22      Iris-setosa
# 23      Iris-setosa
# 24   Iris-virginica
# 25      Iris-setosa
# 26      Iris-setosa
# 27  Iris-versicolor
# 28  Iris-versicolor
# 29      Iris-setosa
# 30   Iris-virginica
# 31  Iris-versicolor
# 32      Iris-setosa
# 33   Iris-virginica
# 34   Iris-virginica
# 35  Iris-versicolor
# 36      Iris-setosa
# 37  Iris-versicolor
# 38  Iris-versicolor
# 39  Iris-versicolor
# 40   Iris-virginica
# 41      Iris-setosa
# 42   Iris-virginica
# 43      Iris-setosa
# 44      Iris-setosa

# %%
pd.concat([df1, df2],axis = 1)
# Out:
#     Predict           Actual
# 0         2   Iris-virginica
# 1         1  Iris-versicolor
# 2         0      Iris-setosa
# 3         2   Iris-virginica
# 4         0      Iris-setosa
# 5         2   Iris-virginica
# 6         0      Iris-setosa
# 7         1  Iris-versicolor
# 8         2  Iris-versicolor
# 9         1  Iris-versicolor
# 10        2   Iris-virginica
# 11        1  Iris-versicolor
# 12        1  Iris-versicolor
# 13        1  Iris-versicolor
# 14        1  Iris-versicolor
# 15        0      Iris-setosa
# 16        1  Iris-versicolor
# 17        1  Iris-versicolor
# 18        0      Iris-setosa
# 19        0      Iris-setosa
# 20        1   Iris-virginica
# 21        1  Iris-versicolor
# 22        0      Iris-setosa
# 23        0      Iris-setosa
# 24        1   Iris-virginica
# 25        0      Iris-setosa
# 26        0      Iris-setosa
# 27        1  Iris-versicolor
# 28        1  Iris-versicolor
# 29        0      Iris-setosa
# 30        2   Iris-virginica
# 31        1  Iris-versicolor
# 32        0      Iris-setosa
# 33        1   Iris-virginica
# 34        2   Iris-virginica
# 35        1  Iris-versicolor
# 36        0      Iris-setosa
# 37        1  Iris-versicolor
# 38        1  Iris-versicolor
# 39        1  Iris-versicolor
# 40        2   Iris-virginica
# 41        0      Iris-setosa
# 42        2   Iris-virginica
# 43        0      Iris-setosa
# 44        0      Iris-setosa
